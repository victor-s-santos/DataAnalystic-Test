# %% [markdown]
# >In this notebook I am going to reproduce many of the analysis2 dataframes chart as sql chart.

# %%
import os
import pymysql
import dotenv
from dotenv import load_dotenv
load_dotenv()

HOST = os.getenv('HOST')
USER = os.getenv('MYSQL_USER')
PASSWORD = os.getenv('MYSQL_ROOT_PASSWORD')
DB = os.getenv('MYSQL_DATABASE')

connection = pymysql.connect(host=HOST, 
                      user = USER,
                     password = PASSWORD,
                     db = DB)

cursor = connection.cursor()

# %%
#players who has wins > loss
query = "SELECT player_id FROM matchmaking_stats_summary WHERE total_wins > total_loss"

# %%
cursor.execute(query), cursor.fetchall()
# Out:
# (874,
#  ((354985,),
#   (325203,),
#   (35792,),
#   (1129344,),
#   (321178,),
#   (862930,),
#   (681743,),
#   (152301,),
#   (734021,),
#   (1189027,),
#   (322891,),
#   (900185,),
#   (697072,),
#   (806434,),
#   (37264,),
#   (247516,),
#   (683818,),
#   (1076473,),
#   (788326,),
#   (818839,),
#   (808747,),
#   (429762,),
#   (493906,),
#   (1231420,),
#   (730548,),
#   (380580,),
#   (1009267,),
#   (872724,),
#   (561900,),
#   (744522,),
#   (217107,),
#   (44961,),
#   (79275,),
#   (1244042,),
#   (373419,),
#   (483789,),
#   (79275,),
#   (224549,),
#   (521503,),
#   (163286,),
#   (66284,),
#   (25828,),
#   (500034,),
#   (852294,),
#   (771745,),
#   (9669,),
#   (107982,),
#   (1009083,),
#   (560871,),
#   (563035,),
#   (474605,),
#   (729987,),
#   (636583,),
#   (1106686,),
#   (1205943,),
#   (535335,),
#   (499714,),
#   (1020640,),
#   (775069,),
#   (328723,),
#   (100725,),
#   (119182,),
#   (395986,),
#   (775835,),
#   (1025052,),
#   (623959,),
# ...

# %%
#players who has wins < loss
query2 = "SELECT player_id FROM matchmaking_stats_summary WHERE total_wins <= total_loss"

# %%
cursor.execute(query2), cursor.fetchall()
# Out:
# (1183,
#  ((152268,),
#   (679247,),
#   (604607,),
#   (95479,),
#   (679130,),
#   (850067,),
#   (79214,),
#   (1086226,),
#   (641988,),
#   (340916,),
#   (1240338,),
#   (1105202,),
#   (734543,),
#   (876879,),
#   (951356,),
#   (691757,),
#   (1053346,),
#   (399893,),
#   (118964,),
#   (24218,),
#   (929654,),
#   (725562,),
#   (1126728,),
#   (553616,),
#   (604607,),
#   (752878,),
#   (86315,),
#   (73515,),
#   (387499,),
#   (957742,),
#   (254632,),
#   (859155,),
#   (322731,),
#   (832857,),
#   (92926,),
#   (373710,),
#   (233585,),
#   (788267,),
#   (646250,),
#   (47030,),
#   (1218315,),
#   (1101201,),
#   (1273136,),
#   (565283,),
#   (55441,),
#   (1169102,),
#   (113087,),
#   (533302,),
#   (55345,),
#   (141659,),
#   (182276,),
#   (1243965,),
#   (798406,),
#   (715541,),
#   (1053687,),
#   (339996,),
#   (1151290,),
#   (888219,),
#   (45032,),
#   (730270,),
#   (926173,),
#   (325922,),
#   (878728,),
#   (455251,),
#   (1220687,),
# ...
