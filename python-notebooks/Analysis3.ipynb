# %% [markdown]
# >In this notebook I am going to reproduce many of the analysis2 dataframes chart as sql chart.

# %%
import os
import pymysql
import dotenv
from dotenv import load_dotenv
load_dotenv()

HOST = os.getenv('HOST')
USER = os.getenv('MYSQL_USER')
PASSWORD = os.getenv('MYSQL_ROOT_PASSWORD')
DB = os.getenv('MYSQL_DATABASE')

connection = pymysql.connect(host=HOST, 
                      user = USER,
                     password = PASSWORD,
                     db = DB)

cursor = connection.cursor()

# %%
def chart(x, y, xlabel, ylabel, title, chart_type=0):
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    if chart_type == 0:
        return plt.scatter(x,y)
    else:
        return plt.bar(x,y)

# %% [markdown]
# * __Chart 1__: Players whose have total_wins > total_loss:

# %%
import matplotlib.pyplot as plt

query3 = "SELECT matches_played, total_wins, total_loss FROM matchmaking_stats_summary WHERE total_wins > total_loss"

cursor.execute(query3)
wins = []
matches = []
loss = []
lista = cursor.fetchall()
for elements in lista:
    matches.append(elements[0])
    wins.append(elements[1])
    loss.append(elements[2])
chart(matches, wins, "Matches", "Wins", "Relation between total wins and matches played")

# %%
chart(matches, loss, "Matches", "Loss", "Relation between total loss and matches played")

# %% [markdown]
# * __Chart 2__: Players whose have total_loss > total_wins:

# %%
query4 = "SELECT matches_played, total_wins, total_loss FROM matchmaking_stats_summary WHERE total_wins < total_loss"

cursor.execute(query4)
wins = []
matches = []
loss = []
lista = cursor.fetchall()
for elements in lista:
    matches.append(elements[0])
    wins.append(elements[1])
    loss.append(elements[2])
chart(matches, wins, "Matches", "Wins", "Relation between total wins and matches played")

# %%
chart(matches, loss, "Matches", "Loss", "Relation between total loss and matches played")
